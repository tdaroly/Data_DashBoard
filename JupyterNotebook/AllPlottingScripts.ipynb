# %%
#data normalization
import pandas as pd
import numpy as np
df = pd.read_csv("C:\Users\\taher\OneDrive\Desktop\Work\Chirality\htmlDashBoards\Data\FracFocusRegistry_17.csv")
grouped_df = df.groupby(by=["WellName","StateName","CountyName"]).aggregate(np.mean).dropna(axis=1, how='all')
grouped_df = grouped_df.reset_index()
lat = list(grouped_df["Latitude"])
lon = list(grouped_df["Longitude"])
well_names = list(grouped_df["WellName"])

# %%
df1 = df.iloc[:,0:35] # Remember that Python does not slice inclusive of the ending index.
df1
# Out:
#                                    UploadKey           JobStartDate  \
# 0       594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 1       594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 2       594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 3       594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 4       594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 5       594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 6       594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 7       594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 8       594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 9       594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 10      594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 11      594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# 12      594d0502-62b0-4911-9eb9-14b7db0150a9   7/27/2018 5:00:00 AM
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
from enum import Enum     # for enum34, or the stdlib version
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot

plotly.tools.set_credentials_file(username='tdaroly2', api_key='gYvalucu7J5Z8eveMbPR')

trace = dict(
type="scattergeo",
locationmode="USA-states",
visible=True,
lon=lon,
lat=lat,
ids=well_names,
text= well_names,
mode="markers",
hoverinfo="text",
    hoverlabel = dict(
    bgcolor ="magenta",
    bordercolor="black",
        font = dict(
        family="Comic Sans",
        size=25
            
        )
    ),
fillcolor="magenta",

marker = dict(
            size = 8,
            opacity = 0.8,
            reversescale = True,
            autocolorscale = False,
            symbol = 'square',
            line = dict(
                width=1,
                color='rgba(102, 102, 102)'
            ))
    
)

data =[trace]

layout =dict(title="So its gonna be forever",
             geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = "rgb(250, 250, 250)",
            subunitcolor = "rgb(217, 217, 217)",
            countrycolor = "rgb(217, 217, 217)",
            countrywidth = 0.5,
            subunitwidth = 1.5
        )
             
            )
fig=go.Figure(data=data,layout=layout)
#py.iplot(fig)
plot(fig)
# Out:
# 'file://C:\\Users\\taher\\OneDrive\\Desktop\\Work\\Chirality\\htmlDashBoards\\JupyterNotebook\\temp-plot.html'

# %%
options=[
            {'label': 'New York City', 'value': 'NYC'},
            {'label': u'Montréal', 'value': 'MTL'},
            {'label': 'San Francisco', 'value': 'SF'}
        ]

# %%
#options=[]
options.append(dict(label="Taher",value="Kk"))

# %%
plot(fig)
# Out:
# 'file://C:\\Users\\taher\\OneDrive\\Desktop\\Work\\Chirality\\htmlDashBoards\\JupyterNotebook\\temp-plot.html'

# %%
df_filtered = df.loc[df["WellName"]=="PRONGHORN FEDERAL 21-13-2PH"]["PercentHighAdditive"].to_frame().reset_index().drop(['index'],axis=1).reset_index().rename(index=str, columns={"index": "X"})


trace=go.Bar(x=df_filtered["X"],y=df_filtered["PercentHighAdditive"])
data=[trace]
layout={}
fig=go.Figure(data=data,layout=layout)
plot(fig)
# Out:
# 'file://C:\\Users\\taher\\OneDrive\\Desktop\\Work\\Chirality\\htmlDashBoards\\JupyterNotebook\\temp-plot.html'

# %%
import plotly.plotly as py
import plotly.graph_objs as go

mapbox_access_token = 'pk.eyJ1IjoidGRhcm9seTEiLCJhIjoiY2pxNmh3MnB3MjVnejQ2cDN5MjFtb2gyZSJ9.4sGKnxvJpGKBWLKt0jGVxw'

data = [
    go.Scattermapbox(
        lat=lat,
        lon=lon,
    
        ids=well_names,
text= well_names,
mode="markers",
hoverinfo="text",
        marker=dict(
            size=14
        ),
      
    )
]

layout = go.Layout(
    autosize=True,
    
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=45,
            lon=-73
        ),
        pitch=0,
        zoom=5
    ),
)

fig = dict(data=data, layout=layout)
plot(fig)
# Out:
# 'file://C:\\Users\\taher\\OneDrive\\Desktop\\Work\\Chirality\\htmlDashBoards\\JupyterNotebook\\temp-plot.html'

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
import numpy as np

x = list(df.loc[df["WellName"]=="PRONGHORN FEDERAL 21-13-2PH"]["PercentHFJob"])
y = list(df.loc[df["WellName"]=="PRONGHORN FEDERAL 21-13-2PH"]["PercentHighAdditive"])
z = list(df.loc[df["WellName"]=="PRONGHORN FEDERAL 21-13-2PH"]["TVD"])

trace = go.Scatter3d(
    x=x, y=y, z=z,
    marker=dict(
        size=4,
        color=z,
        colorscale='Viridis',
    ),
    line=dict(
        color='#1f77b4',
        width=1
    )
)

data = [trace]

layout = dict(
    width=800,
    height=700,
    autosize=False,
    title='Well Bore',
    scene=dict(
        xaxis=dict(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        yaxis=dict(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        zaxis=dict(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        camera=dict(
            up=dict(
                x=0,
                y=0,
                z=1
            ),
            eye=dict(
                x=-1.7428,
                y=1.0707,
                z=0.7100,
            )
        ),
        aspectratio = dict( x=1, y=1, z=0.7 ),
        aspectmode = 'manual'
    ),
)

fig = dict(data=data, layout=layout)

plot(fig)
# Out:
# 'file://C:\\Users\\taher\\OneDrive\\Desktop\\Work\\Chirality\\htmlDashBoards\\JupyterNotebook\\temp-plot.html'

# %%
x = list(df.loc[df["WellName"]=="PRONGHORN FEDERAL 21-13-2PH"]["PercentHFJob"])
y = list(df.loc[df["WellName"]=="PRONGHORN FEDERAL 21-13-2PH"]["PercentHighAdditive"])
z = list(df.loc[df["WellName"]=="PRONGHORN FEDERAL 21-13-2PH"]["TVD"])

# %%
import plotly.plotly as py
import plotly.graph_objs as go


trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=list(df.loc[df["WellName"]=="PRONGHORN FEDERAL 21-13-2PH"]["TVD"]),
    mode='markers',
    marker=dict(
        size=12,
                colorscale='Viridis',   # choose a colorscale

        line=dict(
            color='rgba(217, 217, 217, 0.14)',
            width=0.5
        ),
        opacity=0.8
    )
)


data = [trace1]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data, layout=layout)
plot(fig)
# Out:
# 'file://C:\\Users\\taher\\OneDrive\\Desktop\\Work\\Chirality\\htmlDashBoards\\JupyterNotebook\\temp-plot.html'

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/iris.csv')
df.head()

def brownian_motion(T = 1, N = 100, mu = 0.1, sigma = 0.01, S0 = 20):
    dt = float(T)/N
    t = np.linspace(0, T, N)
    W = np.random.standard_normal(size = N)
    W = np.cumsum(W)*np.sqrt(dt) # standard brownian motion
    X = (mu-0.5*sigma**2)*t + sigma*W
    S = S0*np.exp(X) # geometric brownian motion
    return S

dates = pd.date_range('2012-01-01', '2013-02-22')
T = (dates.max()-dates.min()).days / 365
N = dates.size
start_price = 100
y = pd.Series(
    brownian_motion(T, N, sigma=10, S0=start_price), index=dates)
z = pd.Series(
    brownian_motion(T, N, sigma=12, S0=start_price), index=dates)

trace = go.Scatter3d(
    x=list(dates), y=y, z=z,
    marker=dict(
        size=4,
        color=z,
        colorscale='Viridis',
    ),
    line=dict(
        color='#1f77b4',
        width=1
    )
)

data = [trace]

layout = dict(
    width=800,
    height=700,
    autosize=False,
    title='Iris dataset',
    scene=dict(
        xaxis=dict(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        yaxis=dict(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        zaxis=dict(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        camera=dict(
            up=dict(
                x=0,
                y=0,
                z=1
            ),
            eye=dict(
                x=-1.7428,
                y=1.0707,
                z=0.7100,
            )
        ),
        aspectratio = dict( x=1, y=1, z=0.7 ),
        aspectmode = 'manual'
    ),
)

fig = dict(data=data, layout=layout)

plot(fig)
# Out:
# 'file://C:\\Users\\taher\\OneDrive\\Desktop\\Work\\Chirality\\htmlDashBoards\\JupyterNotebook\\temp-plot.html'

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/plotly/dash-oil-and-gas-demo/master/data/wellspublic.csv")
list(df)
# Out:
# C:\Users\taher\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2714: DtypeWarning:
#
# Columns (41,47) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
list(df)
# Out:
# ['API_WellNo',
#  'Cnty',
#  'Hole',
#  'SideTrck',
#  'Completion',
#  'Well_Name',
#  'Company_name',
#  'Operator_number',
#  'Well_Type',
#  'Map_Symbol',
#  'Well_Status',
#  'Date_Status',
#  'Date_Permit_Application',
#  'Permit_Issued',
#  'Date_Spudded',
#  'Date_Total_Depth',
#  'Date_Well_Completed',
#  'Date_well_plugged',
#  'Date_well_confidential',
#  'confid',
#  'town',
#  'quad',
#  'quadsec',
#  'Producing_name',
#  'Producing_formation',
#  'Financial_security',
#  'Slant',
#  'County',
#  'Region',
#  'State_lease',
#  'Proposed_depth',
#  'Surface_location',
#  'Surface_Longitude',
#  'Surface_latitude',
#  'Bottom_hole_location',
#  'Bottom_hole_longitude',
#  'Bottom_hole_latitude',
#  'True_vertical_depth',
#  'Measured_depth',
#  'Kickoff',
#  'DrilledDepth',
#  'Elevation',
#  'Original_well_type',
#  'Permit_Fee',
#  'Objective_formation',
#  'Depth_Fee',
#  'Spacing',
#  'Spacing_Acres',
#  'Integration',
#  'Dt_Hearing',
#  'Dt_Mod',
#  'LINK']

# %%
app.layout = html.Div([

    html.Div([ 
    html.H1(children='Hello Dash',id="para"),

    html.Div(children='''
      Map.py
    ''')]),

    dcc.Graph(
        id='histogram',
        figure=hist
        
    ),
    dcc.Graph(id="geoMap",
    figure=fig),

    html.Div(id="bottom",children=[
        html.H2(children="This is the start of how it ever ends")
    ])

])

# %%
options=[
        {'label': 'New York City', 'value': 'NYC'},
        {'label': 'Montréal', 'value': 'MTL'},
        {'label': 'San Francisco', 'value': 'SF'}
    ]

# %%
options=[]

for el in grouped_df["StateName"].unique():
    dic=[];
    dic=dict(label=el,value=el)
    options.append(dic)

# %%
df_occurences = df.loc[df["CountyName"]=="Andrews"].groupby(by=["OperatorName"]).size().to_frame().reset_index().rename(index=str, columns={0: "Occurences"})
df_occurences
# Out:
#              OperatorName  Occurences
# 0  Pacesetter Energy, LLC          66
# 1       Ring Energy, Inc.         124
# 2   XTO Energy/ExxonMobil         929
# 3          Zarvona Energy         120

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from colour import Color

countyName="Weld"
def piechart(countyName):
    df_occurences = df.loc[df["CountyName"]==countyName].groupby(by=["OperatorName"]).size().to_frame().reset_index().rename(index=str, columns={0: "Occurences"})
    labels = list(df_occurences["OperatorName"].sort_values())
    values = list(df_occurences["Occurences"].sort_values())
    red = Color("#66ffea")
    colors = list(red.range_to(Color("#f442f4"),len(labels)))
    colors = [item.hex for item in colors]
    trace = go.Pie(labels=labels,hole=0.4, values=values,
                   hoverinfo='label+percent',
                   textinfo='value',
                   marker=dict(colors=colors, 
                               line=dict(color='#000000', width=2)))

    data=[trace]
    data.append(trace)
    layout=dict(title="This is the start of how it ever ends",
               )
    fig=go.Figure(data=data,layout=layout)
    return fig




piechart = piechart(countyName)
plot(piechart)
# Out:
# 'file://C:\\Users\\taher\\OneDrive\\Desktop\\Work\\Chirality\\htmlDashBoards\\JupyterNotebook\\temp-plot.html'

# %%
trace = go.Pie(labels=labels, values=values,
               hoverinfo='label+percent', textinfo='value', 
               textfont=dict(size=20),
               marker=dict(colors=colors, 
                           line=dict(color='#000000', width=2)))
# Out:
# ['#f00', '#d58e00', '#72aa00', '#008000']

# %%
import plotly.plotly as py
import plotly.graph_objs as go


def scatterplot(wellname):

    df_scatter = df.loc[df["WellName"]=="Harris-Cook 70 107HB"]
    if len(df_scatter.groupby(by=["IngredientName"]).count()) == 0:
        print("Its been said and done")
        return None
    else:
        df_scatter = dff.groupby(by=["IngredientName"]).mean()["PercentHFJob"].to_frame().reset_index()

    trace = dict(
    x=df_scatter["IngredientName"],
    y=df_scatter["PercentHFJob"],
    marker = dict(color="magenta",size=12),
    mode="markers",
    text = df["IngredientName"],
    type = "scatter",
    hoverinfo="text",
    hoveron="points",
    orientation="v")

    data = [trace]
    layout = dict(height=500,
    width=900,)

    fig = go.Figure(data=data, layout=layout)
    return fig
# Out:
#                                        IngredientName  PercentHFJob
# 0          (2-hydroxyethyl)trimethylammonium chloride      0.000151
# 1                                         Acetic acid      0.000050
# 2                Acrylamide sodium acrylate copolymer      0.000140
# 3              Acrylamide/ammonium acrylate copolymer      0.000175
# 4                                   Ammonium chloride      0.000036
# 5                         Diammonium peroxidisulphate      0.000058
# 6   Distillates (petroleum), solvent-dewaxed heavy...      0.000031
# 7          Distillates, petroleum, hydrotreated light      0.000145
# 8                                   Hydrochloric acid      0.001019
# 9                                  Magnesium chloride      0.000032
# 10                Polyethylene glycol monohexyl ether      0.000075
# 11                         Quartz, Crystalline silica      0.118765
# 12            SDS and Non-SDS components listed below      0.000000
# ...

# %%
dff = df.loc[df["WellName"]=="Harris-Cook 70 107HB"]
dff = dff.groupby(by=["IngredientName"]).mean()["PercentHFJob"].to_frame().reset_index()
print(dff)
# Out:
#                                        IngredientName  PercentHFJob
# 0          (2-hydroxyethyl)trimethylammonium chloride       0.01349
# 1                                         Acetic acid       0.00448
# 2                Acrylamide sodium acrylate copolymer       0.01251
# 3              Acrylamide/ammonium acrylate copolymer       0.01562
# 4                                   Ammonium chloride       0.00318
# 5                         Diammonium peroxidisulphate       0.00516
# 6   Distillates (petroleum), solvent-dewaxed heavy...       0.00276
# 7          Distillates, petroleum, hydrotreated light       0.01294
# 8                                   Hydrochloric acid       0.09088
# 9                                  Magnesium chloride       0.00282
# 10                Polyethylene glycol monohexyl ether       0.00671
# 11                         Quartz, Crystalline silica      10.59666
# 12            SDS and Non-SDS components listed below       0.00000
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
from enum import Enum     # for enum34, or the stdlib version
from plotly.offline import download_plotlyjs, init_notebook_mode, plot,iplot
from colour import Color


def gradient_generator(length,start,stop):
    start = Color(start)
    stop = Color(stop)
    colors = list(start.range_to(Color(stop),length))
    colors = [item.hex for item in colors]
    return colors

wellname="Sims 7-8 #1"
#plot(fig)

colors = gradient_generator(5,"red","black")

def hist(wellname):
    df_filtered = df.loc[df["WellName"]==wellname]["PercentHighAdditive"].to_frame().sort_values(by=["PercentHighAdditive"]).reset_index().drop(['index'],axis=1).reset_index().rename(index=str, columns={"index": "X"})
    trace=go.Bar(x=df_filtered["X"],y=df_filtered["PercentHighAdditive"],marker=dict(
        color=gradient_generator(len(df_filtered["X"]),"#66ffea","#f442f4")
    ),opacity=0.75)
    data=[trace]
    

    
    
    layout=dict(title="Well {}".format(wellname),
       paper_bgcolor='#111111',
        plot_bgcolor='#111111',
        font=dict(family='Work Sans', size=15, color='white'),
        xaxis=dict(
            title="Value"
        ),
        yaxis=dict(
            title="PercentHighAdditive"
        )
               
                )

    hist=go.Figure(data=data,layout=layout)
    return hist
plot(hist(wellname))
# Out:
# 'file://C:\\Users\\taher\\OneDrive\\Desktop\\Work\\Chirality\\htmlDashBoards\\JupyterNotebook\\temp-plot.html'

# %%
# !pip install pyorbital
# Out:
# ...
#   Running setup.py bdist_wheel for pyorbital: started
#   Running setup.py bdist_wheel for pyorbital: finished with status 'done'
#   Stored in directory: C:\Users\taher\AppData\Local\pip\Cache\wheels\61\98\c2\f3d62d678a2bd91da090e1392e3230c57db8bfb89e9d457f29
# Successfully built pyorbital
# ...
